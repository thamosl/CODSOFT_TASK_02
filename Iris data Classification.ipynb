# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("D:\Dataset\IRIS.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             4.3          3.0           1.1          0.1        0
# 1             4.4          2.9           1.4          0.2        0
# 2             4.4          3.0           1.3          0.2        0
# 3             4.4          3.2           1.3          0.2        0
# 4             4.5          2.3           1.3          0.3        0
# ..            ...          ...           ...          ...      ...
# 145           7.7          3.8           6.7          2.2        2
# 146           7.7          2.6           6.9          2.3        2
# 147           7.7          2.8           6.7          2.0        2
# 148           7.7          3.0           6.1          2.3        2
# 149           7.9          3.8           6.4          2.0        2
#
# [150 rows x 5 columns]

# %%
print(df.species)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %%
pd.isnull(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
a=plt.scatter(df['sepal_length'],df['sepal_width'])

# %%
b=plt.scatter(df['petal_length'],df['petal_width'])

# %%
X=df[['sepal_length','sepal_width','petal_length','petal_width']]
y=df[['species']]

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             4.3          3.0           1.1          0.1
# 1             4.4          2.9           1.4          0.2
# 2             4.4          3.0           1.3          0.2
# 3             4.4          3.2           1.3          0.2
# 4             4.5          2.3           1.3          0.3
# ..            ...          ...           ...          ...
# 145           7.7          3.8           6.7          2.2
# 146           7.7          2.6           6.9          2.3
# 147           7.7          2.8           6.7          2.0
# 148           7.7          3.0           6.1          2.3
# 149           7.9          3.8           6.4          2.0
#
# [150 rows x 4 columns]

# %%
y
# Out:
#      species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
len(X_train)
# Out:
# 120

# %%
len(X_test)
# Out:
# 30

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 clf.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined

# %%
clf.predict(X_test)
# Out:
# array([[ 1.4900119 ],
#        [ 1.94627728],
#        [ 0.03015732],
#        [ 1.2170852 ],
#        [-0.04137904],
#        [ 1.39779884],
#        [ 1.80680659],
#        [ 1.27540401],
#        [-0.03553211],
#        [ 1.01673171],
#        [-0.03298633],
#        [ 1.80728793],
#        [-0.15982095],
#        [ 0.02477964],
#        [-0.07676462],
#        [ 1.91863696],
#        [ 1.56201199],
#        [ 0.15500391],
#        [ 1.61457357],
#        [ 0.05402293],
#        [ 2.25110096],
#        [ 2.04763782],
#        [ 1.89409585],
#        [-0.0056084 ],
#        [ 1.02711245],
#        [-0.00306202],
#        [ 1.33457593],
#        [ 1.09335472],
#        [ 1.08080774],
#        [ 1.71157791]])

# %%
y_test
# Out:
#      species
# 87         2
# 111        2
# 10         0
# 91         1
# 49         0
# 60         1
# 72         2
# 67         1
# 39         0
# 55         1
# 66         0
# 142        2
# 53         0
# 1          0
# 19         0
# 112        2
# 85         1
# 38         0
# 21         2
# 35         0
# 102        2
# 132        2
# 126        2
# 24         0
# 61         1
# 2          0
# 95         1
# 90         1
# 76         1
# 117        2

# %%
clf.score(X_test,y_test)
# Out:
# 0.9312424611360933

# %% [markdown]
# Finally the Classification of the iris dataset is splitted into training and testing dataset by classification model and these data sets are trained using LinearRegression and finally it is tested and got output confidence of 93%.The relationship between the petal and sepal sizes are to be analysed by the scatter plot visualization by using the pandas and matplot library packages.All are done using the sklearn packages and its components.The values 0-irisSetosa,1-irisVersicolor,2-irisvirginica.
